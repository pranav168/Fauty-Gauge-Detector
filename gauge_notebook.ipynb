# %%
import numpy as np
import matplotlib.pyplot as plt

from gauge import tester
from tsplot import utility

import warnings                                                              
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
'''
Default Needle 2
'''
white_pixel_count_needle_2 = tester().pixel_count('needle2.mp4', 1, 42, 1180, 1290)
utility().tsplot(list(white_pixel_count_needle_2), lags=80)

# %%
'''
Stable Needle
'''
white_pixel_count_stable_needle =tester().pixel_count('stable-needle.mp4', cropX1=180, cropY1=350, cropX2=350, cropY2=550)
utility().tsplot(white_pixel_count_stable_needle, lags=80)

# %%
'''
Default Needle 1
'''
white_pixel_count_needle_1 = tester().pixel_count('needle.mp4', cropX1=1, cropY1=100, cropX2=900, cropY2=1000)
utility().tsplot(list(white_pixel_count_needle_1), lags=40)

# %%
white_pixel_count_stable_needle_2 = tester().pixel_count('stable-needle2.mp4', cropX1=340, cropY1=380, cropX2=530, cropY2=570)
utility().tsplot(list(white_pixel_count_stable_needle_2), lags=100)
